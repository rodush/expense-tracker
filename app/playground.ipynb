# %%
categories = [
    "Mortgage",
    "Health insurance",
    "Public transport",
    "Electricity",
    "Auto",
    "Moto",
    "Insurance",
    "Health & Beauty",
    "Grocery",
    "Other",
    "Household",
    "Drinks",
    "Toys",
    "Sport",
    "Restaurants",
    "Mobile",
    "Hobby",
    "Clothing",
    "Alcohol",
    "Presents",
    "Credit Card",
    "Psychologist",
    "Internet",
    "Pocket money",
    "Health",
    "Wellbeing",
    "Sports",
    "Peuterspeelzaal",
    "Central heating",
    "Services",
    "Subscription",
    "Water",
    "Entertainment",
]

# %% [markdown]
# *Print sorted categories so we can use them in config*

# %%
print(sorted(categories))

# %%
import pandas as pd

df = pd.read_excel(
    "file:///home/rodush/Downloads/XLS260412224302-test.xls",
    sheet_name="Sheet0",
    usecols=["Date", "Description", "Amount"],
)

# %%
print(df.info())

# %%
df.groupby(df["Date"]).sum().sort_values("Amount", ascending=True)
